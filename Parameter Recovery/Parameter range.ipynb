# %%
import sys
import os
sys.path.append(os.path.dirname(os.path.abspath(os.getcwd())))

import numpy as np
import pandas as pd
import cmdstanpy

# %%
# For ANNRDM full
stan_output_dir = "../Results/stan_results/ANN-RDM_full_FC"

# %%
# Loading fitted data
fit = cmdstanpy.from_csv(stan_output_dir)
# Out:
# 12:05:07 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 1 had 3 divergent transitions (1.2%)
# 	Chain 2 had 2 divergent transitions (0.8%)
# 	Use function "diagnose()" to see further information.

# %%
likelihoods = fit.stan_variables()['log_lik']

# %%
twenty_percent_count = round(likelihoods.shape[0] * 0.2)
max_ll_indecies = np.argsort(likelihoods.sum(axis=1))[::-1][:twenty_percent_count]

# %%
parameters_range_df = pd.DataFrame([], columns=["max", "min"])
for parameter in fit.stan_variables().keys():
    max_val = fit.stan_variables()[parameter][max_ll_indecies].max()
    min_val = fit.stan_variables()[parameter][max_ll_indecies].min()
    parameters_range_df.loc[parameter] = [max_val, min_val]

# %%
parameters_range_df
# Out:
#                                   max       min
# mu_g                        -0.350684 -4.265740
# mu_m                         0.788480 -0.729960
# mu_threshold_word            1.821610 -0.074808
# mu_threshold_nonword         1.837150 -0.648687
# mu_alpha                     3.071770 -0.558148
# mu_b                         2.527390 -2.139460
# mu_k_1                       3.474830 -0.548457
# mu_k_2                       4.145770 -0.978064
# sd_g                         2.747390  0.002471
# sd_m                         1.572670  0.008630
# sd_threshold_word            2.745700  0.006578
# sd_threshold_nonword         2.941150  0.002201
# sd_alpha                     3.636560  0.089345
# sd_b                         2.819020  0.168508
# sd_k_1                       2.879100  0.010857
# sd_k_2                       3.316360  0.514643
# z_g                          2.181110 -2.343700
# z_m                          1.894680 -2.211380
# z_threshold_word             1.822690 -2.305160
# ...
