# %%
import sys
import os
sys.path.append(os.path.dirname(os.path.abspath(os.getcwd())))

import numpy as np
import pandas as pd
import cmdstanpy
from utils.utils import get_parameters_range

# %%
# For ANNRDM full
stan_output_dir = "../Estimations/Results/hierarchical/stan_results/ANN-RDM_full_FT"

# %%
ranges = get_parameters_range(stan_output_dir)
# Out:
# 18:59:22 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 1 had 7 divergent transitions (1.4%)
# 	Chain 2 had 5 divergent transitions (1.0%)
# 	Use function "diagnose()" to see further information.

# %%
ranges
# Out:
#                                    max        min
# mu_g                         -1.037330  -4.918930
# mu_m                          1.197720  -1.010130
# mu_threshold_word             2.323260  -1.440430
# mu_threshold_nonword          2.687830  -0.852302
# mu_alpha                      3.153110  -1.889730
# mu_b                          1.449450  -2.258100
# mu_k_1                        3.408780  -0.610669
# mu_k_2                        4.008280  -0.069708
# sd_g                          2.612800   0.015692
# sd_m                          3.042380   0.561119
# sd_threshold_word             3.811450   0.131179
# sd_threshold_nonword          3.615780   0.003164
# sd_alpha                      4.669020   0.613408
# sd_b                          3.678860   0.001961
# sd_k_1                        2.979100   0.382906
# sd_k_2                        3.261150   0.358006
# z_g                           2.277070  -2.976210
# z_m                           2.439670  -3.657650
# z_threshold_word              2.484500  -3.135070
# z_threshold_nonword           2.486390  -1.887840
# z_alpha                       3.841960  -1.226540
# z_b                           1.715530  -2.352410
# z_k_1                         2.719450  -3.398450
# z_k_2                         3.215700  -2.103390
# drift_word_t                  3.964810   0.004546
# drift_nonword_t               3.001390   0.005823
# threshold_t_word              1.926950   1.008850
# threshold_t_nonword           2.125630   1.440240
# ndt_t                         0.329410   0.101578
# alpha_sbj                    11.466400   1.236660
# b_sbj                         0.729921   0.067762
# k_1_sbj                       3.591900   0.568956
# k_2_sbj                       4.433470   1.804980
# threshold_sbj_word            1.926950   1.008850
# threshold_sbj_nonword         2.125630   1.440240
# g_sbj                         0.275607   0.000157
# m_sbj                         1.823750   0.005455
# transf_mu_alpha               3.194940   0.140729
# transf_mu_b                   1.660280   0.099437
# transf_mu_k_1                 3.441330   0.433720
# transf_mu_k_2                 4.026280   0.658901
# transf_mu_threshold_word      2.416710   0.212549
# transf_mu_threshold_nonword   2.753640   0.355176
# transf_mu_g                   0.303357   0.007280
# transf_mu_m                   1.461530   0.310547
# log_lik                       1.152880 -23.025900
